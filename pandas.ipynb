# %% [markdown]
# <a href="https://colab.research.google.com/github/adityarathore063/Machine-learning-and-AI/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
iris_df = pd.read_csv("/content/iris_data_set.csv")

# %%
print(iris_df)
print(type(iris_df))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
data_frame = iris_df.copy()

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.tail(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
print(data_frame.shape)
print(data_frame.dtypes)
# Out:
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data_frame.species
data_frame["species"]
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
# checking for null value in data frame
data_frame.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
data_frame.iloc[0:2,0:3]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4

# %%
# droping a column in data_frame
data_frame.drop(0)
data_frame.head()

# for making inplace we can use
# data_frame.drop(0, inplace=True)
# data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
new_df = data_frame.drop(0)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
new_df.index
# Out:
# RangeIndex(start=1, stop=150, step=1)

# %%
new_df.index[0]
# Out:
# 1

# %%
new_df.drop(new_df.index[0], inplace=True)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
new_df.petal_width > 0.2
# Out:
# 2      False
# 3      False
# 4      False
# 5       True
# 6       True
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: petal_width, Length: 148, dtype: bool

# %%
new_df[new_df.petal_width > 0.2]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [116 rows x 5 columns]

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    148.000000   148.000000    148.000000   148.000000
# mean       5.854730     3.051351      3.790541     1.212162
# std        0.827695     0.434950      1.754657     0.759332
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df[new_df.petal_width > 0.2].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    116.000000   116.000000    116.000000   116.000000
# mean       6.105172     2.963793      4.438793     1.496552
# std        0.740369     0.419606      1.402406     0.599410
# min        4.500000     2.000000      1.300000     0.300000
# 25%        5.600000     2.700000      4.000000     1.200000
# 50%        6.100000     3.000000      4.700000     1.500000
# 75%        6.600000     3.200000      5.400000     1.925000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df[new_df.species == 'virginica']
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 106           4.9          2.5           4.5          1.7  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# ...

# %%
new_df[new_df.species == 'virginica'].describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
print(new_df.head())
print(new_df.iloc[0]) # work as index or position
print(new_df.loc[3]) # work as labels
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object
# sepal_length       4.6
# sepal_width        3.1
# petal_length       1.5
# petal_width        0.2
# species         setosa
# Name: 3, dtype: object

# %%
# adding a new column

new_df.loc[0] = [4.5, 3.1, 1.5, 0.3, 'setosa']
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
new_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# 0             4.5          3.1           1.5          0.3     setosa

# %%
new_df.reset_index(drop=True, inplace = True)
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           4.7          3.2           1.3          0.2  setosa
# 1           4.6          3.1           1.5          0.2  setosa
# 2           5.0          3.6           1.4          0.2  setosa
# 3           5.4          3.9           1.7          0.4  setosa
# 4           4.6          3.4           1.4          0.3  setosa

# %%
new_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.845638     3.051678      3.775168     1.206040
# std        0.832327     0.433497      1.758758     0.760443
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
new_df["color"] = "white"
new_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  color
# 0           4.7          3.2           1.3          0.2  setosa  white
# 1           4.6          3.1           1.5          0.2  setosa  white
# 2           5.0          3.6           1.4          0.2  setosa  white
# 3           5.4          3.9           1.7          0.4  setosa  white
# 4           4.6          3.4           1.4          0.3  setosa  white

# %%
del new_df['sepal_width']
new_df.head()
# Out:
#    sepal_length  petal_length  petal_width species  color
# 0           4.7           1.3          0.2  setosa  white
# 1           4.6           1.5          0.2  setosa  white
# 2           5.0           1.4          0.2  setosa  white
# 3           5.4           1.7          0.4  setosa  white
# 4           4.6           1.4          0.3  setosa  white

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.shape
# Out:
# (150, 5)

# %%
data_frame.iloc[2:3, 2:4] = np.nan

# %%
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           NaN          NaN  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data_frame.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    149.000000   149.000000
# mean       5.843333     3.054000      3.775168     1.205369
# std        0.828066     0.433594      1.758720     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data_frame.dropna(inplace = True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
data_frame.reset_index(drop=True, inplace= True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           1.5          0.2  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
data_frame.iloc[2:3,2:4] = np.nan
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.6          3.1           NaN          NaN  setosa
# 3           5.0          3.6           1.4          0.2  setosa
# 4           5.4          3.9           1.7          0.4  setosa

# %%
# filling the missing data with mean
data_frame.petal_length.fillna(data_frame.petal_length.mean(), inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000          0.2  setosa
# 1           4.9          3.0      1.400000          0.2  setosa
# 2           4.6          3.1      3.790541          NaN  setosa
# 3           5.0          3.6      1.400000          0.2  setosa
# 4           5.4          3.9      1.700000          0.4  setosa

# %%
# filling the missing data with the mean of the setosa data

temp = data_frame[data_frame.species == "setosa"]
print(temp.head())

data_frame.petal_width.fillna(temp.petal_width.mean(), inplace=True)
data_frame.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000          0.2  setosa
# 1           4.9          3.0      1.400000          0.2  setosa
# 2           4.6          3.1      3.790541          NaN  setosa
# 3           5.0          3.6      1.400000          0.2  setosa
# 4           5.4          3.9      1.700000          0.4  setosa
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5      1.400000     0.200000  setosa
# 1           4.9          3.0      1.400000     0.200000  setosa
# 2           4.6          3.1      3.790541     0.245833  setosa
# 3           5.0          3.6      1.400000     0.200000  setosa
# 4           5.4          3.9      1.700000     0.400000  setosa
